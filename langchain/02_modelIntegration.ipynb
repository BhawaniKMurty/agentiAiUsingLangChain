# %% [markdown]
# ### Model integration with OpenAI,GoogleGemini & GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["ANTHROPIC_API_KEY"] = os.getenv("ANTHROPIC_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
# GROQ Model Integration
from langchain.chat_models import init_chat_model
model=init_chat_model("groq:meta-llama/llama-4-scout-17b-16e-instruct")
model
response=model.invoke("Hello! How r u..?")
print(response.content)
# Out:
# Hello! I'm doing well, thanks for asking! I'm a large language model, so I don't have feelings like humans do, but I'm always happy to chat and help with any questions or topics you'd like to discuss. How about you? How's your day going so far?

# %%
# Google Gemini Integration
import os
from langchain.chat_models import init_chat_model
model=init_chat_model("google_genai:gemini-2.5-flash-lite")
response=model.invoke("What is LLM. Explain in oneLiner.")
print(response.content)
# Out:
# A **Large Language Model (LLM)** is an AI model trained on vast amounts of text data to understand, generate, and process human language.

# %% [markdown]
# ### specific to LLMs

# %%
### chatOpenAI

from langchain_openai import ChatOpenAI
model=ChatOpenAI(model="gpt-4.1-mini")
response=model.invoke("What is LLM. Explain in oneLiner.")
print(response.content)

# %%
# Google Gemini Integration
import os
from langchain_google_genai import ChatGoogleGenerativeAI
model=ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response=model.invoke("What is LLM. Explain in oneLiner.")
print(response.content)
# Out:
# LLMs are AI models that can understand and generate human-like text by learning patterns from vast amounts of data.

# %%
# Groq Model Integration
import os
from langchain_groq import ChatGroq
model=ChatGroq(model="qwen/qwen3-32b")
response=model.invoke("What is LLM. Explain in oneLiner.")
print(response.content)
# Out:
# <think>
# Okay, the user is asking for a one-liner explanation of what an LLM is. Let me start by recalling the basics. LLM stands for Large Language Model. They are a type of AI that processes and generates human-like text.
#
# I need to make sure the answer is concise. The key points are: AI, trained on vast text data, generates coherent responses, and handles various tasks. Maybe mention the scale, like "massive scale" or "billions of parameters." Also, include tasks like translation, summarization, etc.
#
# Wait, the user wants a one-liner. So I have to condense all that without being too vague. Let me check if I have the components right. AI model, trained on large datasets, processes and generates text, handles multiple tasks. Maybe add "complex patterns" or "understanding language."
#
# ...
